# %%
# Note: The model and training settings do not follow the reference settings
# from the paper. The settings are chosen such that the example can easily be
# run on a small dataset with a single GPU.

import pytorch_lightning as pl
import torch
import torchvision
from torch import nn
import  sys
sys.path.append("C:/Users/isxzl/OneDrive/Code/AutoSSL")
from lightly.loss import BarlowTwinsLoss
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.transforms.simclr_transform import SimCLRTransform
import torch.distributed as dist

path_to_train_cifar10="../Datasets/cifar10/train/"
path_to_test_cifar10="../Datasets/cifar10/test/"
class BarlowTwins(pl.LightningModule):
    def __init__(self,MonitoringbyKNN=None):
        super().__init__()
        resnet = torchvision.models.resnet18()
        self.backbone = nn.Sequential(*list(resnet.children())[:-1])
        self.projection_head = BarlowTwinsProjectionHead(512, 2048, 2048)
        self.criterion = BarlowTwinsLoss()

        if MonitoringbyKNN:
            self.dataloader_kNN = MonitoringbyKNN[0]
            self.num_classes = MonitoringbyKNN[1]
            self.knn_k = 200 
            self.knn_t = 0.1
            self.max_accuracy = 0.0
            self._train_features: Optional[Tensor] = None
            self._train_targets: Optional[Tensor] = None
            self._val_predicted_labels: List[Tensor] = []
            self._val_targets: List[Tensor] = []
        else:
            self.dataloader_kNN=None
        
        
    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        
        return z

    def training_step(self, batch, batch_index):
        (x0, x1) = batch[0]
        z0 = self.forward(x0)
        z1 = self.forward(x1)
        loss = self.criterion(z0, z1)
        self.log('train_loss', loss)
        return loss

    def configure_optimizers(self):
        optim = torch.optim.SGD(self.parameters(), lr=0.06)
        return optim

    def on_validation_epoch_start(self) -> None:
        if self.dataloader_kNN:
            train_features = []
            train_targets = []
            with torch.no_grad():
                for data in self.dataloader_kNN:
                    img, target, _ = data
                    img = img.to(self.device)
                    target = target.to(self.device)
                    feature = self.backbone(img).squeeze()
                    feature = F.normalize(feature, dim=1)
                    if (
                        dist.is_available()
                        and dist.is_initialized()
                        and dist.get_world_size() > 0
                    ):
                        # gather features and targets from all processes
                        feature = torch.cat(dist.gather(feature), 0)
                        target = torch.cat(dist.gather(target), 0)
                    train_features.append(feature)
                    train_targets.append(target)
            self._train_features = torch.cat(train_features, dim=0).t().contiguous()
            self._train_targets = torch.cat(train_targets, dim=0).t().contiguous()

    def validation_step(self, batch, batch_idx) -> None:
        if self.dataloader_kNN:
            # we can only do kNN predictions once we have a feature bank
            if self._train_features is not None and self._train_targets is not None:
                images, targets, _ = batch
                feature = self.backbone(images).squeeze()
                feature = F.normalize(feature, dim=1)
                predicted_labels = knn_predict(
                    feature,
                    self._train_features,
                    self._train_targets,
                    self.num_classes,
                    self.knn_k,
                    self.knn_t,
                )
                if dist.is_initialized() and dist.get_world_size() > 0:
                    # gather predictions and targets from all processes
                    predicted_labels = torch.cat(dist.gather(predicted_labels), 0)
                    targets = torch.cat(dist.gather(targets), 0)

                self._val_predicted_labels.append(predicted_labels.cpu())
                self._val_targets.append(targets.cpu())

    def on_validation_epoch_end(self) -> None:
        if self.dataloader_kNN:
            if self._val_predicted_labels and self._val_targets:
                predicted_labels = torch.cat(self._val_predicted_labels, dim=0)
                targets = torch.cat(self._val_targets, dim=0)
                top1 = (predicted_labels[:, 0] == targets).float().sum()
                acc = top1 / len(targets)
                if acc > self.max_accuracy:
                    self.max_accuracy = acc.item()
                self.log("kNN_accuracy", acc * 100.0, prog_bar=True)

            self._val_predicted_labels.clear()
            self._val_targets.clear()
            
from lightly.data import LightlyDataset
import torch.nn as nn
import torchvision
test_transforms = torchvision.transforms.Compose(
    [
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225],
        ),
    ]
)

transform = SimCLRTransform(input_size=32)

dataset = LightlyDataset(input_dir=path_to_train_cifar10, transform=transform)

testdataset = LightlyDataset(input_dir=path_to_test_cifar10, transform=test_transforms)


dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=512,
    shuffle=True,
    drop_last=True,
    num_workers=4,
)

testdataloader = torch.utils.data.DataLoader(
    testdataset,
    batch_size=512,
    shuffle=False,
    drop_last=False,
    num_workers=4,
)            
            

model = BarlowTwins(MonitoringbyKNN=[testdataloader,10])




# or create a dataset from a folder containing images or videos:
# dataset = LightlyDataset("path/to/folder", transform=transform)

# %%
from autoSSL.utils import ck_callback, join_dir,ContinuousCSVLogger
import torch.nn.functional as F
from autoSSL.utils.knn import knn_predict
dirr="experiment_checkpoints/vanilla/" 
accelerator = "gpu"
trainer = pl.Trainer(max_epochs=50, devices=1, 
                     accelerator=accelerator,
                     callbacks=[ck_callback(dirr)],
                     logger=ContinuousCSVLogger(save_dir=dirr),check_val_every_n_epoch =5)

trainer.fit(model=model, train_dataloaders=dataloader,val_dataloaders=testdataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name            | Type                      | Params
# --------------------------------------------------------------
# 0 | backbone        | Sequential                | 11.2 M
# 1 | projection_head | BarlowTwinsProjectionHead | 9.4 M
# 2 | criterion       | BarlowTwinsLoss           | 0
# --------------------------------------------------------------
# 20.6 M    Trainable params
# 0         Non-trainable params
# 20.6 M    Total params
# 82.496    Total estimated model params size (MB)
# Epoch 0: 100%|████████████████████████████████████████████████████████████████| 97/97 [00:26<00:00,  3.69it/s, v_num=3]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 43.62it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 40.53it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 36.93it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 32.49it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 33.22it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 31.85it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 31.78it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 31.17it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 32.89it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 32.10it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 32.46it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 32.02it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 25.85it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 26.06it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 26.49it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 26.66it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 24.07it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 24.50it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 25.01it/s]
# Epoch 0: 100%|████████████████████████████████████████████| 97/97 [00:39<00:00,  2.44it/s, v_num=3, kNN_accuracy=18.90]
# Epoch 1: 100%|████████████████████████████████████████████| 97/97 [00:26<00:00,  3.61it/s, v_num=3, kNN_accuracy=18.90]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 31.35it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 41.37it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 46.66it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 48.64it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 50.41it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 51.67it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 52.61it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 53.50it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 39.26it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 38.07it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 37.73it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 37.21it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 29.11it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 28.63it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 28.80it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 29.26it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 25.29it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 25.96it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 25.99it/s]
# Epoch 1: 100%|████████████████████████████████████████████| 97/97 [00:40<00:00,  2.38it/s, v_num=3, kNN_accuracy=22.50]
# Epoch 2: 100%|████████████████████████████████████████████| 97/97 [00:28<00:00,  3.42it/s, v_num=3, kNN_accuracy=22.50]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 43.62it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 40.13it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 37.16it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 35.99it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 35.20it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 34.69it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 33.68it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 34.08it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 36.77it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 39.11it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 38.79it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 37.55it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 30.46it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 30.20it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 30.61it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 30.25it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 27.24it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 27.52it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 28.23it/s]
# Epoch 2: 100%|████████████████████████████████████████████| 97/97 [00:42<00:00,  2.27it/s, v_num=3, kNN_accuracy=22.70]
# Epoch 3: 100%|████████████████████████████████████████████| 97/97 [00:26<00:00,  3.65it/s, v_num=3, kNN_accuracy=22.70]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 50.17it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 39.35it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 41.23it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 36.65it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 35.96it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 36.15it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 30.40it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 32.89it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 35.00it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 36.62it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 33.90it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 35.15it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 26.40it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 26.98it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 25.31it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 26.49it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 22.82it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 23.45it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 23.77it/s]
# Epoch 3: 100%|████████████████████████████████████████████| 97/97 [00:40<00:00,  2.40it/s, v_num=3, kNN_accuracy=22.80]
# Epoch 4: 100%|████████████████████████████████████████████| 97/97 [00:29<00:00,  3.34it/s, v_num=3, kNN_accuracy=22.80]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 36.47it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 26.93it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 23.89it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 23.74it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 25.86it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 28.13it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 29.82it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 31.54it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 32.54it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 33.39it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 31.35it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 29.80it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 25.70it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 25.91it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 24.59it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 24.87it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 22.98it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 23.64it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 23.03it/s]
# Epoch 4: 100%|████████████████████████████████████████████| 97/97 [00:43<00:00,  2.23it/s, v_num=3, kNN_accuracy=22.60]
# Epoch 5: 100%|████████████████████████████████████████████| 97/97 [00:32<00:00,  2.95it/s, v_num=3, kNN_accuracy=22.60]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▊                                                      | 1/20 [00:00<00:00, 125.42it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 95.56it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 86.00it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 78.69it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 67.33it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 57.60it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 56.41it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 54.78it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 29.27it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 30.45it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 32.31it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 33.91it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 22.76it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 23.97it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 25.16it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 26.36it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 20.72it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 21.70it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 22.69it/s]
# Epoch 5: 100%|████████████████████████████████████████████| 97/97 [00:47<00:00,  2.03it/s, v_num=3, kNN_accuracy=24.00]
# Epoch 6: 100%|████████████████████████████████████████████| 97/97 [00:29<00:00,  3.34it/s, v_num=3, kNN_accuracy=24.00]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 37.16it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 35.51it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 31.51it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 27.97it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 25.99it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 29.22it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 32.36it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 35.20it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 37.78it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 37.93it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 36.60it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 34.74it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 29.64it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 29.60it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 29.36it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 28.77it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 26.12it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 26.50it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 26.75it/s]
# Epoch 6: 100%|████████████████████████████████████████████| 97/97 [00:43<00:00,  2.24it/s, v_num=3, kNN_accuracy=24.10]
# Epoch 7: 100%|████████████████████████████████████████████| 97/97 [00:27<00:00,  3.48it/s, v_num=3, kNN_accuracy=24.10]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▊                                                      | 1/20 [00:00<00:00, 167.21it/s]
# Validation DataLoader 0:  10%|█████▋                                                   | 2/20 [00:00<00:00, 125.41it/s]
# Validation DataLoader 0:  15%|████████▌                                                | 3/20 [00:00<00:00, 103.79it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 85.39it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 80.91it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 79.21it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 72.03it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 57.53it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 28.62it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 30.26it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 31.04it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 32.23it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 23.31it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 24.20it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 24.51it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 25.72it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 21.27it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 22.21it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 22.11it/s]
# Epoch 7: 100%|████████████████████████████████████████████| 97/97 [00:42<00:00,  2.27it/s, v_num=3, kNN_accuracy=25.20]
# Epoch 8: 100%|████████████████████████████████████████████| 97/97 [00:29<00:00,  3.28it/s, v_num=3, kNN_accuracy=25.20]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 47.78it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 44.59it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 44.27it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 41.81it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 40.29it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 39.83it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 41.40it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 42.55it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 37.05it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 33.20it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 34.04it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 35.08it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 27.30it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 26.05it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 26.58it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 26.97it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 24.01it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 23.60it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 24.21it/s]
# Epoch 8: 100%|████████████████████████████████████████████| 97/97 [00:44<00:00,  2.20it/s, v_num=3, kNN_accuracy=25.80]
# Epoch 9: 100%|████████████████████████████████████████████| 97/97 [00:29<00:00,  3.30it/s, v_num=3, kNN_accuracy=25.80]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 34.60it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 29.72it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 26.29it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 27.48it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 27.26it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 25.89it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 26.35it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 27.35it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 29.55it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 30.13it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 29.83it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 30.32it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 24.96it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 25.13it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 25.04it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 26.31it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 23.24it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 23.30it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 23.71it/s]
# Epoch 9: 100%|████████████████████████████████████████████| 97/97 [00:43<00:00,  2.21it/s, v_num=3, kNN_accuracy=25.80]
# Epoch 10: 100%|███████████████████████████████████████████| 97/97 [00:31<00:00,  3.11it/s, v_num=3, kNN_accuracy=25.80]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 50.17it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 46.67it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 44.93it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 41.80it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 40.62it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 39.73it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 35.74it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 36.32it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 33.44it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 34.01it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 31.58it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 32.50it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 25.55it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 26.18it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 25.14it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 25.89it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 22.97it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 23.78it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 23.25it/s]
# Epoch 10: 100%|███████████████████████████████████████████| 97/97 [00:46<00:00,  2.11it/s, v_num=3, kNN_accuracy=26.20]
# Epoch 11: 100%|███████████████████████████████████████████| 97/97 [00:30<00:00,  3.20it/s, v_num=3, kNN_accuracy=26.20]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 87.20it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 72.96it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 70.81it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 65.25it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 64.73it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 63.70it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 61.60it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 61.27it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 36.48it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 36.82it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 37.22it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 38.10it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 27.49it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 27.33it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 28.13it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 29.13it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 24.45it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 24.69it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 25.60it/s]
# Epoch 11: 100%|███████████████████████████████████████████| 97/97 [00:45<00:00,  2.14it/s, v_num=3, kNN_accuracy=27.20]
# Epoch 12: 100%|███████████████████████████████████████████| 97/97 [00:30<00:00,  3.21it/s, v_num=3, kNN_accuracy=27.20]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 71.67it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 57.33it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 53.27it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 50.48it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 47.10it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 46.85it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 44.73it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 43.86it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 35.20it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 34.90it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 35.20it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 35.15it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 25.70it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 26.48it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 26.78it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 27.68it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 23.20it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 24.02it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 24.64it/s]
# Epoch 12: 100%|███████████████████████████████████████████| 97/97 [00:45<00:00,  2.14it/s, v_num=3, kNN_accuracy=28.70]
# Epoch 13: 100%|███████████████████████████████████████████| 97/97 [00:29<00:00,  3.27it/s, v_num=3, kNN_accuracy=28.70]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 44.57it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 44.09it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 42.09it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 42.02it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 41.45it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 40.95it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 41.07it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 40.53it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 35.06it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 35.14it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 35.26it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 35.62it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 24.24it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 24.86it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 23.53it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 24.30it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 20.76it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 21.48it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 21.48it/s]
# Epoch 13: 100%|███████████████████████████████████████████| 97/97 [00:44<00:00,  2.17it/s, v_num=3, kNN_accuracy=30.40]
# Epoch 14: 100%|███████████████████████████████████████████| 97/97 [00:31<00:00,  3.07it/s, v_num=3, kNN_accuracy=30.40]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 21.57it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 27.67it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 28.80it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 28.46it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 29.33it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 31.52it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 31.99it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 33.51it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 31.63it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 27.87it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 28.89it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 28.03it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 24.65it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 23.41it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 23.46it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 23.83it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 21.48it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 21.23it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 21.17it/s]
# Epoch 14: 100%|███████████████████████████████████████████| 97/97 [00:47<00:00,  2.06it/s, v_num=3, kNN_accuracy=30.50]
# Epoch 15: 100%|███████████████████████████████████████████| 97/97 [00:30<00:00,  3.17it/s, v_num=3, kNN_accuracy=30.50]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 48.93it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 40.53it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 40.40it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 35.51it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 36.09it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 37.39it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 37.55it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 38.77it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 34.53it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 34.65it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 33.64it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 31.85it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 24.89it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 24.73it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 24.79it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 25.06it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 22.47it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 23.09it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 22.73it/s]
# Epoch 15: 100%|███████████████████████████████████████████| 97/97 [00:44<00:00,  2.16it/s, v_num=3, kNN_accuracy=30.70]
# Epoch 16: 100%|███████████████████████████████████████████| 97/97 [00:30<00:00,  3.14it/s, v_num=3, kNN_accuracy=30.70]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 62.71it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 54.23it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 53.26it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 49.24it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 49.42it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 44.75it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 42.05it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 39.54it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 30.97it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 31.60it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 32.41it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 31.03it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 23.00it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 24.01it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 24.91it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 24.68it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 18.51it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 19.20it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 19.90it/s]
# Epoch 16: 100%|███████████████████████████████████████████| 97/97 [00:45<00:00,  2.11it/s, v_num=3, kNN_accuracy=30.80]
# Epoch 17: 100%|███████████████████████████████████████████| 97/97 [00:29<00:00,  3.26it/s, v_num=3, kNN_accuracy=30.80]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 35.20it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 29.73it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 32.19it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 34.15it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 35.07it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 35.41it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 36.77it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 38.40it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 35.20it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 32.52it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 32.94it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 32.10it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 26.48it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 25.58it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 25.04it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 25.26it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 22.35it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 22.60it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 22.44it/s]
# Epoch 17: 100%|███████████████████████████████████████████| 97/97 [00:44<00:00,  2.19it/s, v_num=3, kNN_accuracy=32.40]
# Epoch 18: 100%|███████████████████████████████████████████| 97/97 [00:30<00:00,  3.21it/s, v_num=3, kNN_accuracy=32.40]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 47.78it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 45.08it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 36.48it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 35.05it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 32.36it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 33.44it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 32.82it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 31.78it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 31.51it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 30.13it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 31.17it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 31.11it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 23.67it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 23.93it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 24.12it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 24.64it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 21.37it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 21.74it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 22.49it/s]
# Epoch 18: 100%|███████████████████████████████████████████| 97/97 [00:44<00:00,  2.16it/s, v_num=3, kNN_accuracy=33.20]
# Epoch 19: 100%|███████████████████████████████████████████| 97/97 [00:29<00:00,  3.30it/s, v_num=3, kNN_accuracy=33.20]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                                                               | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                                  | 0/20 [00:00<?, ?it/s]
# Validation DataLoader 0:   5%|██▉                                                       | 1/20 [00:00<00:00, 35.83it/s]
# Validation DataLoader 0:  10%|█████▊                                                    | 2/20 [00:00<00:00, 29.51it/s]
# Validation DataLoader 0:  15%|████████▋                                                 | 3/20 [00:00<00:00, 31.35it/s]
# Validation DataLoader 0:  20%|███████████▌                                              | 4/20 [00:00<00:00, 33.03it/s]
# Validation DataLoader 0:  25%|██████████████▌                                           | 5/20 [00:00<00:00, 33.78it/s]
# Validation DataLoader 0:  30%|█████████████████▍                                        | 6/20 [00:00<00:00, 33.91it/s]
# Validation DataLoader 0:  35%|████████████████████▎                                     | 7/20 [00:00<00:00, 34.09it/s]
# Validation DataLoader 0:  40%|███████████████████████▏                                  | 8/20 [00:00<00:00, 35.36it/s]
# Validation DataLoader 0:  45%|██████████████████████████                                | 9/20 [00:00<00:00, 28.89it/s]
# Validation DataLoader 0:  50%|████████████████████████████▌                            | 10/20 [00:00<00:00, 28.62it/s]
# Validation DataLoader 0:  55%|███████████████████████████████▎                         | 11/20 [00:00<00:00, 29.55it/s]
# Validation DataLoader 0:  60%|██████████████████████████████████▏                      | 12/20 [00:00<00:00, 30.44it/s]
# Validation DataLoader 0:  65%|█████████████████████████████████████                    | 13/20 [00:00<00:00, 22.16it/s]
# Validation DataLoader 0:  70%|███████████████████████████████████████▉                 | 14/20 [00:00<00:00, 22.36it/s]
# Validation DataLoader 0:  75%|██████████████████████████████████████████▊              | 15/20 [00:00<00:00, 23.22it/s]
# Validation DataLoader 0:  80%|█████████████████████████████████████████████▌           | 16/20 [00:00<00:00, 23.75it/s]
# Validation DataLoader 0:  85%|████████████████████████████████████████████████▍        | 17/20 [00:00<00:00, 20.14it/s]
# Validation DataLoader 0:  90%|███████████████████████████████████████████████████▎     | 18/20 [00:00<00:00, 20.57it/s]
# Validation DataLoader 0:  95%|██████████████████████████████████████████████████████▏  | 19/20 [00:00<00:00, 21.23it/s]
# Epoch 19: 100%|███████████████████████████████████████████| 97/97 [00:44<00:00,  2.20it/s, v_num=3, kNN_accuracy=33.50]
# Epoch 20:   9%|████                                        | 9/97 [00:08<01:27,  1.00it/s, v_num=3, kNN_accuracy=33.50]
